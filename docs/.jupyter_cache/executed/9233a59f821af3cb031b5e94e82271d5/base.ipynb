# %%
import scarf
import scarf.plotting as splt

scarf.set_verbosity('WARNING')

scarf.fetch_dataset(
    'tenx_5K_pbmc_rnaseq',
    save_path='scarf_datasets',
    as_zarr=True,
)
ds = scarf.DataStore(
    'scarf_datasets/tenx_5K_pbmc_rnaseq/data.zarr',
    nthreads=4,
    min_features_per_cell=10,
)
ds.filter_cells(
    attrs=['RNA_nCounts', 'RNA_nFeatures', 'RNA_percentMito'],
    highs=[15000, 4000, 15],
    lows=[1000, 500, 0],
    reset_previous=True,
)
ds.mark_hvgs(min_cells=20, top_n=500, show_plot=False)
ds.make_graph(feat_key='hvgs', k=11, dims=15, n_centroids=100)
ds.run_umap(n_epochs=150, spread=5, min_dist=1, parallel=True)
ds.run_leiden_clustering(resolution=0.5)

# %%
ds.run_umap(
    n_epochs=150,
    spread=5,
    min_dist=1,
    parallel=True,
    use_density_map=True,
    label='densMAP',
)
splt.embedding(ds, layout_key='RNA_densMAP')
# Out:
# PlotResult(axes=1, tables=0, legends=0, scales=1, owns_figure=True, rendered=True)

# %%
ds.run_tsne(
    alpha=10,
    box_h=1,
    early_iter=250,
    max_iter=500,
    parallel=True,
)
splt.embedding(ds, layout_key='RNA_tSNE')
# Out:
# parallel=True is not supported by the sgtsnepi Python backend; running single-threaded
# Number of vertices: 3940
# Embedding dimensions: 2
# Rescaling parameter λ: 1
# Early exag. multiplier α: 10
# Maximum iterations: 500
# Early exag. iterations: 250
# Learning rate: 200
# Box side length h: 1
# Drop edges originating from leaf nodes? 0
# Number of processes: 1
# 14 out of 3940 nodes already stochastic
# Skipping λ rescaling...
# m = 3940 | n = 3940 | nnz = 64030
# Setting-up parallel (double-precision) FFTW: 1
# Iteration 1: error is 4.32941
# Iteration 50: error is 3.91775 (50 iterations in 0.059151 seconds)
# Iteration 100: error is 3.87611 (50 iterations in 0.052171 seconds)
# Iteration 150: error is 3.88191 (50 iterations in 0.052436 seconds)
# Iteration 200: error is 3.89927 (50 iterations in 0.055299 seconds)
# Iteration 250: error is 3.91134 (50 iterations in 0.052042 seconds)
# Iteration 300: error is 3.10273 (50 iterations in 0.054876 seconds)
# Iteration 350: error is 2.89955 (50 iterations in 0.066652 seconds)
# Iteration 400: error is 2.78472 (50 iterations in 0.08506 seconds)
# Iteration 450: error is 2.76277 (50 iterations in 0.082974 seconds)
# Iteration 499: error is 2.7586 (50 iterations in 0.077754 seconds)
#  --- Time spent in each module ---
#  Attractive forces: 0.131337 sec [21.5674%] |  Repulsive forces: 0.477623 sec [78.4326%]
# PlotResult(axes=1, tables=0, legends=0, scales=1, owns_figure=True, rendered=True)

# %%
n_clusters = int(
    ds.cells.to_pandas_dataframe(
        columns=['RNA_leiden_cluster'], key='I'
    )['RNA_leiden_cluster'].nunique()
)
ds.run_clustering(n_clusters=n_clusters)
splt.embedding(
    ds,
    layout_key='RNA_UMAP',
    color_by='RNA_cluster',
)
# Out:
# PlotResult(axes=1, tables=0, legends=1, scales=2, owns_figure=True, rendered=True)

# %%
splt.cluster_tree(ds, cluster_key='RNA_cluster', width=1)
# Out:
# PlotResult(axes=1, tables=4, legends=1, scales=2, owns_figure=True, rendered=True)
