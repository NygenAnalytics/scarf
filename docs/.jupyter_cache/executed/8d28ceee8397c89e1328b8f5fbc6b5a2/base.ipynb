# %%
import scarf
import scarf.plotting as splt

scarf.set_verbosity("WARNING")
scarf.__version__
# Out:
# '1.0.0'

# %%
scarf.fetch_dataset(dataset_name="tenx_10K_pbmc-v1_atacseq", save_path="scarf_datasets")

# %%
reader = scarf.CrH5Reader("scarf_datasets/tenx_10K_pbmc-v1_atacseq/data.h5")
reader.assayFeats
# Out:
#             ATAC
# type       Peaks
# start          0
# end        89796
# nFeatures  89796

# %%
writer = scarf.CrToZarr(
    reader,
    zarr_loc="scarf_datasets/tenx_10K_pbmc-v1_atacseq/data.zarr",
    chunk_size=(1000, 2000),
)
writer.dump(batch_size=1000)

# %%
ds = scarf.DataStore("scarf_datasets/tenx_10K_pbmc-v1_atacseq/data.zarr", nthreads=4)

# %%
ds.auto_filter_cells()

# %%
ds.mark_prevalent_peaks(top_n=25000)

# %%
ds.ATAC.feats.head()
# Out:
#       I                 ids               names  dropOuts  nCells  \
# 0  True  chr1:565107-565550  chr1:565107-565550      8645      83
# 1  True  chr1:569174-569639  chr1:569174-569639      8529     199
# 2  True  chr1:713460-714823  chr1:713460-714823      6242    2486
# 3  True  chr1:752422-753038  chr1:752422-753038      8296     432
# 4  True  chr1:762106-763359  chr1:762106-763359      6850    1878
#
#    I__prevalent_peaks  stats_I_prevalence
# 0               False            0.206181
# 1               False            0.350725
# 2                True            1.993573
# 3                True            0.680701
# 4                True            1.570790

# %%
ds.make_graph(
    feat_key="prevalent_peaks",
    k=21,
    dims=50,
    n_centroids=100,
    lsi_skip_first=True,
)

# %%
ds.run_umap(n_epochs=500, min_dist=0.1, spread=1, parallel=True)

# %%
ds.run_leiden_clustering(resolution=0.6)

# %%
ds.cells.head()
# Out:
#        I                 ids               names  ATAC_nFeatures  ATAC_UMAP2  \
# 0   True  AAACGAAAGAGCGAAA-1  AAACGAAAGAGCGAAA-1          5546.0   -4.227288
# 1   True  AAACGAAAGAGTTTGA-1  AAACGAAAGAGTTTGA-1          6586.0   -4.623529
# 2   True  AAACGAAAGCGAGCTA-1  AAACGAAAGCGAGCTA-1          9214.0   -1.634067
# 3  False  AAACGAAAGGCTTCGC-1  AAACGAAAGGCTTCGC-1         30325.0         NaN
# 4   True  AAACGAAAGTGCTGAG-1  AAACGAAAGTGCTGAG-1          4922.0   -4.324438
#
#    ATAC_nCounts  ATAC_UMAP1  ATAC_leiden_cluster
# 0       13187.0  -13.650312                    1
# 1       16074.0  -10.231584                    4
# 2       28009.0    7.284991                    7
# 3      221747.0         NaN                   -1
# 4       11440.0  -14.363647                    1

# %%
splt.embedding(
    ds,
    layout_key="ATAC_UMAP",
    color_by="ATAC_leiden_cluster",
).figure

# %%
scarf.fetch_dataset(dataset_name="annotations", save_path="scarf_datasets")

# %%
ds.add_melded_assay(
    from_assay="ATAC",
    external_bed_fn="scarf_datasets/annotations/human_GRCh37_gencode_v38_gene_body.bed.gz",
    peaks_col="ids",
    renormalization=False,
    assay_label="GeneScores",
    assay_type="RNA",
)
# Out:
# Chromosome chrM not in the input peak coordinates
# Minimum cell count (6.539499236477921) is lower than size factor multiplier (1000)

# %%
ds
# Out:
# DataStore has 8426 (8728) cells with 2 assays: GeneScores ATAC
#    Cell metadata:
#             'I', 'ids', 'names', 'ATAC_nFeatures', 'GeneScores_nCounts',
#             'GeneScores_percentMito', 'GeneScores_percentRibo', 'ATAC_nCounts', 'ATAC_UMAP2', 'ATAC_leiden_cluster',
#             'GeneScores_nFeatures', 'ATAC_UMAP1'
#    GeneScores assay has 28357 (62446) features and following metadata:
#             'I', 'ids', 'names', 'nCells', 'dropOuts',
#
#    ATAC assay has 86049 (89796) features and following metadata:
#             'I', 'ids', 'names', 'nCells', 'I__prevalent_peaks',
#             'dropOuts'

# %%
splt.embedding(
    ds,
    layout_key="ATAC_UMAP",
    from_assay="GeneScores",
    color_by=["CD3D", "MS4A1", "LEF1", "NKG7", "TREM1", "LYZ"],
    clip_fraction=0.01,
    n_columns=3,
    sort_values=True,
).figure
