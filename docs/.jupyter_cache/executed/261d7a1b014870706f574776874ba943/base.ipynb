# %%
import scarf

scarf.set_verbosity('WARNING')

# %%
dataset = scarf.cytebase.connect("scarf_docs").download_dataset(
    name='tenx_10K_pbmc-v1_atacseq',
    destination='scarf_datasets'
)

# %%
reader = scarf.CrH5Reader(f'{dataset}/data.h5')
reader.assayFeats
# Out:
#             ATAC
# type       Peaks
# start          0
# end        89796
# nFeatures  89796

# %%
writer = scarf.CrToZarr(
    reader,
    zarr_loc=f'{dataset}/data.zarr',
)
writer.dump(batch_size=1000)

# %%
ds = scarf.DataStore(
    f'{dataset}/data.zarr',
    nthreads=4
)

# %%
qc_cols = [
    c for c in ('ATAC_nCounts', 'ATAC_nFeatures')
    if c in ds.cells.columns
]
ds.plots.distribution(
    keys=qc_cols,
    kind='violin',
    max_points=2000,
)

# %%
ds.auto_filter_cells(show_qc_plots=True)

# %%
ds.mark_prevalent_peaks(top_n=25000)

# %%
ds.ATAC.feats.head()
# Out:
#       I                 ids               names  nCells  I__prevalent_peaks  \
# 0  True  chr1:565107-565550  chr1:565107-565550      83               False
# 1  True  chr1:569174-569639  chr1:569174-569639     199               False
# 2  True  chr1:713460-714823  chr1:713460-714823    2486                True
# 3  True  chr1:752422-753038  chr1:752422-753038     432                True
# 4  True  chr1:762106-763359  chr1:762106-763359    1878                True
#
#    dropOuts  stats_I_prevalence
# 0      8645            0.206181
# 1      8529            0.350725
# 2      6242            1.993573
# 3      8296            0.680701
# 4      6850            1.570790

# %%
ds.run_normalization(feat_key='prevalent_peaks')
ds.run_lsi(dims=50, skip_first=True)
ds.build_embedding_initialization()
ds.build_ann_index()
ds.query_neighbors(k=21)
ds.build_connectivity_map()

ds.load_graph()
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 176946 stored elements and shape (8426, 8426)>

# %%
ds.run_umap(
    n_epochs=500,
    min_dist=0.1, 
    spread=1, 
    parallel=True
)

# %%
ds.run_leiden_clustering(resolution=0.6)

# %%
ds.cells.to_pandas_dataframe(
    ['ATAC_UMAP1', 'ATAC_UMAP2', 'ATAC_leiden_cluster']
).head()
# Out:
#    ATAC_UMAP1  ATAC_UMAP2  ATAC_leiden_cluster
# 0   -0.797547   -4.296547                    1
# 1   -4.268912   -4.166382                    5
# 2    9.238015    6.568140                    9
# 3         NaN         NaN                   -1
# 4   -0.138457   -4.218270                    2

# %%
ds.plots.embedding(
    layout_key='ATAC_UMAP',
    color_by='ATAC_leiden_cluster',
)

# %%
annotations = scarf.cytebase.connect("scarf_docs").download_dataset(
    name='annotations',
    destination='scarf_datasets'
)

# %%
ds.add_melded_assay(
    from_assay='ATAC',
    external_bed_fn=f'{annotations}/human_GRCh37_gencode_v38_gene_body.bed.gz',
    peaks_col='ids',
    renormalization=False,
    assay_label='GeneScores',
    assay_type='RNA'
)
# Out:
# Chromosome chrM not in the input peak coordinates
# Minimum cell count (6.539499236477921) is lower than size factor multiplier (1000)

# %%
ds
# Out:
# DataStore has 8426 (8728) cells with 2 assays: ATAC GeneScores
#    Cell metadata:
#             'I', 'ids', 'names', 'GeneScores_percentMito', 'ATAC_UMAP2',
#             'ATAC_UMAP1', 'GeneScores_nCounts', 'GeneScores_percentRibo', 'ATAC_nCounts', 'GeneScores_nFeatures',
#             'ATAC_leiden_cluster', 'ATAC_nFeatures'
#    ATAC assay has 86049 (89796) features and following metadata:
#             'I', 'ids', 'names', 'dropOuts', 'nCells',
#             'I__prevalent_peaks'
#    GeneScores assay has 28357 (62446) features and following metadata:
#             'I', 'ids', 'names', 'dropOuts', 'nCells',

# %%
ds.plots.embedding(
    layout_key='ATAC_UMAP',
    from_assay='GeneScores',
    color_by=['CD3D', 'MS4A1', 'LEF1', 'NKG7', 'TREM1', 'LYZ'],
    clip_fraction=0.01,
    n_columns=3,
    sort_values=True,
)
