# %%
import scarf

scarf.configure_output(level='WARNING', progress=False)

dataset = scarf.cytebase.connect("scarf_docs").download_dataset(
    'tenx_5K_pbmc_rnaseq',
    destination='scarf_datasets',
    zarr=True,
)
ds = scarf.DataStore(
    f'{dataset}/data.zarr',
    nthreads=4,
    min_features_per_cell=10,
)
ds.filter_cells(
    attrs=['RNA_nCounts', 'RNA_nFeatures', 'RNA_percentMito'],
    highs=[15000, 4000, 15],
    lows=[1000, 500, 0],
    reset_previous=True,
)

# HVG columns are stored as `{cell_key}__{hvg_key_name}` (here `I__hvgs`)
if 'I__hvgs' not in ds.RNA.feats.columns:
    ds.mark_hvgs(min_cells=20, top_n=500, show_plot=False)
ds.run_normalization(feat_key='hvgs')
ds.run_pca(dims=15, show_elbow_plot=True)
ds.build_embedding_initialization()
ds.build_ann_index()
ds.query_neighbors(k=11)
ds.build_connectivity_map()
# Always run layout and clustering on this page so prepared stores still demonstrate the APIs
ds.run_umap(n_epochs=150, spread=5, min_dist=1, parallel=True)
ds.run_leiden_clustering(resolution=0.5)

# %%
import scarf.plotting as splt

graph = ds.load_graph(
    from_assay='RNA',
    cell_key='I',
    feat_key='hvgs',
    symmetric=False,
    upper_only=False,
)
splt.graph_qc(graph)

# %%
ds.run_umap(
    n_epochs=150,
    spread=5,
    min_dist=1,
    parallel=True,
    use_density_map=True,
    label='densMAP',
)

# %%
ds.run_tsne(
    alpha=10,
    box_h=1,
    early_iter=250,
    max_iter=500,
)
# Out:
# Number of vertices: 3940
# Embedding dimensions: 2
# Rescaling parameter λ: 1
# Early exag. multiplier α: 10
# Maximum iterations: 500
# Early exag. iterations: 250
# Learning rate: 200
# Box side length h: 1
# Drop edges originating from leaf nodes? 0
# Number of processes: 1
# 17 out of 3940 nodes already stochastic
# Skipping λ rescaling...
# m = 3940 | n = 3940 | nnz = 64874
# Setting-up parallel (double-precision) FFTW: 1
# Iteration 1: error is 4.22822
# Iteration 50: error is 4.02448 (50 iterations in 0.218186 seconds)
# Iteration 100: error is 4.05179 (50 iterations in 0.224033 seconds)
# Iteration 150: error is 4.06758 (50 iterations in 0.230841 seconds)
# Iteration 200: error is 4.0925 (50 iterations in 0.259751 seconds)
# Iteration 250: error is 4.10296 (50 iterations in 0.273308 seconds)
# Iteration 300: error is 3.25947 (50 iterations in 0.287754 seconds)
# Iteration 350: error is 3.04736 (50 iterations in 0.292162 seconds)
# Iteration 400: error is 2.92699 (50 iterations in 0.400783 seconds)
# Iteration 450: error is 2.88134 (50 iterations in 0.413628 seconds)
# Iteration 499: error is 2.87821 (50 iterations in 0.381998 seconds)
#  --- Time spent in each module ---
#  Attractive forces: 0.742297 sec [26.106%] |  Repulsive forces: 2.1011 sec [73.894%]

# %%
layout_keys = [
    key for key in ['RNA_UMAP', 'RNA_densMAP', 'RNA_tSNE']
    if f'{key}1' in ds.cells.columns
]
ds.plots.embedding(
    layout_key=layout_keys,
    color_by='RNA_leiden_cluster',
    n_columns=len(layout_keys),
)

# %%
paris = ds.run_paris_clustering()
ds.plots.embedding(
    layout_key='RNA_UMAP',
    color_by=paris.label_key,
)

# %%
ds.plots.cluster_tree(cluster_key='RNA_paris_cluster', width=1)
