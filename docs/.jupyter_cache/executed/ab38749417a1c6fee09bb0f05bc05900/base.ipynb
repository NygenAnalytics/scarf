# %%
import scarf
import scarf.plotting as splt

scarf.set_verbosity('WARNING')
scarf.__version__
# Out:
# '1.0.0'

# %%
scarf.fetch_dataset(
    dataset_name='tenx_10K_pbmc-v1_atacseq',
    save_path='scarf_datasets'
)

# %%
reader = scarf.CrH5Reader(
    'scarf_datasets/tenx_10K_pbmc-v1_atacseq/data.h5'
)
reader.assayFeats
# Out:
#             ATAC
# type       Peaks
# start          0
# end        89796
# nFeatures  89796

# %%
writer = scarf.CrToZarr(
    reader,
    zarr_loc=f'scarf_datasets/tenx_10K_pbmc-v1_atacseq/data.zarr',
    chunk_size=(1000, 2000)
)
writer.dump(batch_size=1000)

# %%
ds = scarf.DataStore(
    'scarf_datasets/tenx_10K_pbmc-v1_atacseq/data.zarr', 
    nthreads=4
)

# %%
ds.auto_filter_cells()

# %%
ds.mark_prevalent_peaks(top_n=25000)

# %%
ds.ATAC.feats.head()
# Out:
#       I                 ids               names  nCells  dropOuts  \
# 0  True  chr1:565107-565550  chr1:565107-565550      83      8645
# 1  True  chr1:569174-569639  chr1:569174-569639     199      8529
# 2  True  chr1:713460-714823  chr1:713460-714823    2486      6242
# 3  True  chr1:752422-753038  chr1:752422-753038     432      8296
# 4  True  chr1:762106-763359  chr1:762106-763359    1878      6850
#
#    I__prevalent_peaks  stats_I_prevalence
# 0               False            0.206181
# 1               False            0.350725
# 2                True            1.993573
# 3                True            0.680701
# 4                True            1.570790

# %%
ds.make_graph(
    feat_key='prevalent_peaks',
    k=21,
    dims=50,
    n_centroids=100,
    lsi_skip_first=True,
)

# %%
ds.run_umap(
    n_epochs=500,
    min_dist=0.1, 
    spread=1, 
    parallel=True
)
# Out:
# /home/parashar/scarf/scarf/metadata.py:416: RuntimeWarning: overflow encountered in cast
#   a = np.empty(self.N).astype(values.dtype)

# %%
ds.run_leiden_clustering(resolution=0.6)

# %%
ds.cells.head()
# Out:
#        I                 ids               names  ATAC_nFeatures  \
# 0   True  AAACGAAAGAGCGAAA-1  AAACGAAAGAGCGAAA-1          5546.0
# 1   True  AAACGAAAGAGTTTGA-1  AAACGAAAGAGTTTGA-1          6586.0
# 2   True  AAACGAAAGCGAGCTA-1  AAACGAAAGCGAGCTA-1          9214.0
# 3  False  AAACGAAAGGCTTCGC-1  AAACGAAAGGCTTCGC-1         30325.0
# 4   True  AAACGAAAGTGCTGAG-1  AAACGAAAGTGCTGAG-1          4922.0
#
#    ATAC_nCounts  ATAC_UMAP2  ATAC_UMAP1  ATAC_leiden_cluster
# 0       13187.0  -10.802001   -8.643649                    1
# 1       16074.0  -13.855995   -9.202133                    4
# 2       28009.0    2.239404    6.785999                    7
# 3      221747.0         NaN         NaN                   -1
# 4       11440.0  -10.149772   -8.353721                    1

# %%
splt.embedding(
    ds,
    layout_key='ATAC_UMAP',
    color_by='ATAC_leiden_cluster',
).figure;

# %%
scarf.fetch_dataset(
    dataset_name='annotations', 
    save_path='scarf_datasets'
)

# %%
ds.add_melded_assay(
    from_assay='ATAC',
    external_bed_fn='scarf_datasets/annotations/human_GRCh37_gencode_v38_gene_body.bed.gz',
    peaks_col='ids',
    renormalization=False,
    assay_label='GeneScores',
    assay_type='RNA'
)
# Out:
# Chromosome chrM not in the input peak coordinates
# Minimum cell count (6.539499236477921) is lower than size factor multiplier (1000)

# %%
ds
# Out:
# DataStore has 8426 (8728) cells with 2 assays: GeneScores ATAC
#    Cell metadata:
#             'I', 'ids', 'names', 'ATAC_nFeatures', 'GeneScores_percentMito',
#             'ATAC_nCounts', 'GeneScores_percentRibo', 'GeneScores_nCounts', 'ATAC_UMAP2', 'GeneScores_nFeatures',
#             'ATAC_leiden_cluster', 'ATAC_UMAP1'
#    ATAC assay has 86049 (89796) features and following metadata:
#             'I', 'ids', 'names', 'nCells', 'dropOuts',
#             'I__prevalent_peaks'
#    GeneScores assay has 28357 (62446) features and following metadata:
#             'I', 'ids', 'names', 'nCells', 'dropOuts',

# %%
splt.embedding(
    ds,
    layout_key='ATAC_UMAP',
    from_assay='GeneScores',
    color_by=['CD3D', 'MS4A1', 'LEF1', 'NKG7', 'TREM1', 'LYZ'],
    clip_fraction=0.01,
    n_columns=3,
    sort_values=True,
).figure;
