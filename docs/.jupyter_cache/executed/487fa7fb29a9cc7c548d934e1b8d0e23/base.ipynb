# %%
# %load_ext autotime

import scarf
scarf.__version__
# Out:
# '1.0.0'
# time: 1.59 s (started: 2026-06-25 22:36:42 +02:00)

# %%
scarf.fetch_dataset(
    dataset_name='tenx_8K_pbmc_citeseq',
    save_path='scarf_datasets',
    as_zarr=True
)
# Out:
# Downloading :   0%|                                                                                           …
# time: 26.4 s (started: 2026-06-25 22:36:43 +02:00)

# %%
ds = scarf.DataStore(
    'scarf_datasets/tenx_8K_pbmc_citeseq/data.zarr',
    nthreads=4
)
# Out:
# time: 1.05 s (started: 2026-06-25 22:37:10 +02:00)

# %%
ds.show_zarr_tree(depth=1)
# Out:
# /
# ├── ADT
# │   ├── counts (7865, 17) uint32
# │   ├── featureData
# │   └── normed__I__I
# ├── RNA
# │   ├── counts (7865, 33538) uint32
# │   ├── featureData
# │   ├── markers
# │   ├── normed__I__hvgs
# │   └── summary_stats_I
# └── cellData
#     ├── ADT_UMAP1 (7865,) float32
#     ├── ADT_UMAP2 (7865,) float32
#     ├── ADT_leiden_cluster (7865,) int64
#     ├── ADT_nCounts (7865,) float64
#     ├── ADT_nFeatures (7865,) float64
#     ├── I (7865,) bool
#     ├── RNA_UMAP1 (7865,) float32
#     ├── RNA_UMAP2 (7865,) float32
#     ├── RNA_cluster (7865,) int64
#     ├── RNA_leiden_cluster (7865,) int64
#     ├── RNA_nCounts (7865,) float64
#     ├── RNA_nFeatures (7865,) float64
#     ├── RNA_percentMito (7865,) float64
#     ├── RNA_percentRibo (7865,) float64
#     ├── RNA_tSNE1 (7865,) float64
#     ├── RNA_tSNE2 (7865,) float64
#     ├── ids (7865,) <U18
#     └── names (7865,) <U18
#
# time: 104 ms (started: 2026-06-25 22:37:11 +02:00)

# %%
ds.show_zarr_tree(start='cellData')
# Out:
# /cellData
# ├── ADT_UMAP1 (7865,) float32
# ├── ADT_UMAP2 (7865,) float32
# ├── ADT_leiden_cluster (7865,) int64
# ├── ADT_nCounts (7865,) float64
# ├── ADT_nFeatures (7865,) float64
# ├── I (7865,) bool
# ├── RNA_UMAP1 (7865,) float32
# ├── RNA_UMAP2 (7865,) float32
# ├── RNA_cluster (7865,) int64
# ├── RNA_leiden_cluster (7865,) int64
# ├── RNA_nCounts (7865,) float64
# ├── RNA_nFeatures (7865,) float64
# ├── RNA_percentMito (7865,) float64
# ├── RNA_percentRibo (7865,) float64
# ├── RNA_tSNE1 (7865,) float64
# ├── RNA_tSNE2 (7865,) float64
# ├── ids (7865,) <U18
# └── names (7865,) <U18
#   RNA_percentMito: shape=(7865,), dtype=float64, chunks=(100000,)
#   RNA_tSNE2: shape=(7865,), dtype=float64, chunks=(100000,)
#   I: shape=(7865,), dtype=bool, chunks=(100000,)
#   ADT_UMAP2: shape=(7865,), dtype=float32, chunks=(100000,)
#   ADT_nCounts: shape=(7865,), dtype=float64, chunks=(100000,)
#   RNA_percentRibo: shape=(7865,), dtype=float64, chunks=(100000,)
#   names: shape=(7865,), dtype=<U18, chunks=(100000,)
#   ADT_UMAP1: shape=(7865,), dtype=float32, chunks=(100000,)
#   RNA_tSNE1: shape=(7865,), dtype=float64, chunks=(100000,)
#   ADT_nFeatures: shape=(7865,), dtype=float64, chunks=(100000,)
#   RNA_nFeatures: shape=(7865,), dtype=float64, chunks=(100000,)
#   ADT_leiden_cluster: shape=(7865,), dtype=int64, chunks=(100000,)
#   RNA_UMAP2: shape=(7865,), dtype=float32, chunks=(100000,)
#   RNA_leiden_cluster: shape=(7865,), dtype=int64, chunks=(100000,)
#   RNA_nCounts: shape=(7865,), dtype=float64, chunks=(100000,)
#   ids: shape=(7865,), dtype=<U18, chunks=(100000,)
#   RNA_UMAP1: shape=(7865,), dtype=float32, chunks=(100000,)
#   RNA_cluster: shape=(7865,), dtype=int64, chunks=(100000,)
# time: 193 ms (started: 2026-06-25 22:37:11 +02:00)

# %%
ds.show_zarr_tree(start='RNA', depth=1)
# Out:
# /RNA
# ├── counts (7865, 33538) uint32
# ├── featureData
# │   ├── I (33538,) bool
# │   ├── I__hvgs (33538,) bool
# │   ├── dropOuts (33538,) int64
# │   ├── ids (33538,) <U15
# │   ├── nCells (33538,) int64
# │   └── names (33538,) <U16
# ├── markers
# │   └── I__RNA_cluster
# ├── normed__I__hvgs
# │   ├── data (7549, 1995) float64
# │   └── reduction__pca__30__I
# └── summary_stats_I
#     ├── avg (33538,) float64
#     ├── c_var__200__0.1 (33538,) float64
#     ├── normed_n (33538,) float64
#     ├── normed_tot (33538,) float64
#     ├── nz_mean (33538,) float64
#     └── sigmas (33538,) float64
#
#   counts: shape=(7865, 33538), dtype=uint32, chunks=(2000, 1000)
# time: 96.5 ms (started: 2026-06-25 22:37:11 +02:00)

# %%
ds.show_zarr_tree(start='RNA/featureData', depth=1)
# Out:
# /RNA/featureData
# ├── I (33538,) bool
# ├── I__hvgs (33538,) bool
# ├── dropOuts (33538,) int64
# ├── ids (33538,) <U15
# ├── nCells (33538,) int64
# └── names (33538,) <U16
#
#   ids: shape=(33538,), dtype=<U15, chunks=(100000,)
#   I__hvgs: shape=(33538,), dtype=bool, chunks=(100000,)
#   dropOuts: shape=(33538,), dtype=int64, chunks=(100000,)
#   I: shape=(33538,), dtype=bool, chunks=(100000,)
#   names: shape=(33538,), dtype=<U16, chunks=(100000,)
#   nCells: shape=(33538,), dtype=int64, chunks=(100000,)
# time: 68.2 ms (started: 2026-06-25 22:37:11 +02:00)

# %%
ds.cells.head()
# Out:
#       I                 ids               names  RNA_percentMito  ADT_nCounts  \
# 0  True  AAACCCAAGATTGTGA-1  AAACCCAAGATTGTGA-1         8.668831        981.0
# 1  True  AAACCCACATCGGTTA-1  AAACCCACATCGGTTA-1         6.316103       1475.0
# 2  True  AAACCCAGTACCGCGT-1  AAACCCAGTACCGCGT-1         8.056090       7149.0
# 3  True  AAACCCAGTATCGAAA-1  AAACCCAGTATCGAAA-1         9.003215       6831.0
# 4  True  AAACCCAGTCGTCATA-1  AAACCCAGTCGTCATA-1         6.204519       6839.0
#
#    ADT_nFeatures  RNA_tSNE2  ADT_UMAP1  RNA_nFeatures  RNA_cluster  \
# 0           17.0  -18.08830 -13.884989         2194.0            4
# 1           17.0  -14.88920  -5.097915         2093.0            4
# 2           17.0  -18.83030  -7.885502         1518.0            5
# 3           17.0   -3.35003  12.072053          737.0            3
# 4           17.0   -1.37607  13.928782         1240.0            3
#
#    RNA_percentRibo  RNA_tSNE1  RNA_leiden_cluster  RNA_nCounts  RNA_UMAP1  \
# 0        15.259740   -4.26865                   3       6160.0  29.421942
# 1        19.037688    5.02671                   3       6713.0  30.801842
# 2        16.002200  -14.91320                   5       3637.0  29.397541
# 3        18.729904   16.69630                   4       1244.0   5.441914
# 4        16.353887   18.37000                   4       2611.0   7.166490
#
#    RNA_UMAP2  ADT_UMAP2  ADT_leiden_cluster
# 0  -7.417822   9.510007                  16
# 1 -12.649998  10.784672                  15
# 2   4.256729  12.961405                   9
# 3 -32.227364  11.531997                   2
# 4 -30.397615  12.290624                   2
# time: 1.04 s (started: 2026-06-25 22:37:11 +02:00)

# %%
ds.RNA.feats.head()
# Out:
#        I              ids        names  I__hvgs  dropOuts  nCells
# 0  False  ENSG00000243485  MIR1302-2HG    False      7865       0
# 1  False  ENSG00000237613      FAM138A    False      7865       0
# 2  False  ENSG00000186092        OR4F5    False      7865       0
# 3  False  ENSG00000238009   AL627309.1    False      7853      12
# 4  False  ENSG00000239945   AL627309.3    False      7865       0
# time: 201 ms (started: 2026-06-25 22:37:12 +02:00)

# %%
ds.cells.to_pandas_dataframe(
    columns=['ids', 'RNA_UMAP1', 'RNA_UMAP2', 'RNA_cluster']
).set_index('ids')
# Out:
#                     RNA_UMAP1  RNA_UMAP2  RNA_cluster
# ids
# AAACCCAAGATTGTGA-1  29.421942  -7.417822            4
# AAACCCACATCGGTTA-1  30.801842 -12.649998            4
# AAACCCAGTACCGCGT-1  29.397541   4.256729            5
# AAACCCAGTATCGAAA-1   5.441914 -32.227364            3
# AAACCCAGTCGTCATA-1   7.166490 -30.397615            3
# ...                       ...        ...          ...
# TTTGTTGGTTCAAGTC-1  -5.545609  21.742104           18
# TTTGTTGGTTGCATGT-1 -26.972895  -0.762715            9
# TTTGTTGGTTGCGGCT-1  27.239552  -5.230516            4
# TTTGTTGTCGAGTGAG-1 -23.030291 -20.647554            2
# TTTGTTGTCGTTCAGA-1 -10.845096  -2.644977            2
#
# [7865 rows x 3 columns]
# time: 319 ms (started: 2026-06-25 22:37:13 +02:00)

# %%
clusters = ds.cells.fetch('RNA_cluster')
clusters.shape
# Out:
# (7549,)
# time: 121 ms (started: 2026-06-25 22:37:13 +02:00)

# %%
clusters_all = ds.cells.fetch_all('RNA_cluster')
clusters_all.shape
# Out:
# (7865,)
# time: 47.9 ms (started: 2026-06-25 22:37:13 +02:00)

# %%
is_clust_1 = clusters == 1   # is_clust_1 has just 7549 elements (same as the number of cells with value True in `I`)
ds.cells.insert(
    column_name='is_clust1', 
    values=is_clust_1
)
# Out:
# time: 154 ms (started: 2026-06-25 22:37:13 +02:00)

# %%
ds.cells.insert(
    column_name='is_clust1',
    values=is_clust_1
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ds.cells.insert(
#       2     column_name='is_clust1',
#       3     values=is_clust_1
#       4 )
#
# File ~/scarf/scarf/metadata.py:428, in MetaData.insert(self, column_name, values, fill_value, key, overwrite, location, force)
#     424     raise ValueError(
#     425         f"ERROR: {col} is a protected column name in MetaData class."
#     426     )
#     427 if col in self.columns and overwrite is False:
# --> 428     raise ValueError(
#     429         f"ERROR: {col} already exists. Please set `overwrite` to True to overwrite."
#     430     )
#     431 if isinstance(values, list):
#     432     logger.debug(
#     433         "'values' parameter is of `list` type and not `np.ndarray` as expected. The correct dtype "
#     434         "may not be assigned to the column"
#     435     )
#
# ValueError: ERROR: is_clust1 already exists. Please set `overwrite` to True to overwrite.
# time: 260 ms (started: 2026-06-25 22:37:13 +02:00)

# %%
ds.cells.insert(
    column_name='is_clust1', 
    values=is_clust_1, 
    overwrite=True
)
# Out:
# time: 151 ms (started: 2026-06-25 22:37:14 +02:00)

# %%
ds.RNA.rawData
# Out:
# ChunkedArray(shape=(7865, 33538), dtype=uint32, chunksize=(2000, 33538), numblocks=4)
# time: 4.42 ms (started: 2026-06-25 22:37:14 +02:00)

# %%
ds.RNA.normed()
# Out:
# ChunkedArray(shape=(7549, 13550), dtype=float64, chunksize=(2000, 13550), numblocks=4)
# time: 185 ms (started: 2026-06-25 22:37:14 +02:00)

# %%
ds.RNA.normMethod
# Out:
# <function scarf.assay.norm_lib_size(assay, counts: scarf.chunked.ChunkedArray) -> scarf.chunked.ChunkedArray>
# time: 3.77 ms (started: 2026-06-25 22:37:14 +02:00)

# %%
import inspect 

print (inspect.getsource(ds.RNA.normMethod))
# Out:
# def norm_lib_size(assay, counts: ChunkedArray) -> ChunkedArray:
#     """Performs library size normalization on the data. This is the default
#     method for RNA assays.
#
#     Args:
#         assay: An instance of the assay object
#         counts: A chunked array with raw counts data
#
#     Returns:  A chunked array (delayed matrix) containing normalized data.
#     """
#     return assay.sf * counts / assay.scalar.reshape(-1, 1)
#
# time: 2.1 ms (started: 2026-06-25 22:37:14 +02:00)

# %%
def my_cool_normalization_method(assay, counts):
    import numpy as np

    # Calculate total counts for each cell
    lib_size = counts.sum(axis=1).reshape(-1, 1) 
    
    # Library size normalization followed by log2 transformation
    return np.log2(counts/lib_size)

ds.RNA.normMethod = my_cool_normalization_method
# Out:
# time: 914 μs (started: 2026-06-25 22:37:14 +02:00)

# %%
ds.RNA.normMethod = scarf.assay.norm_dummy
# Out:
# time: 567 μs (started: 2026-06-25 22:37:14 +02:00)

# %%
ds.show_zarr_tree(start='RNA/normed__I__hvgs')
# Out:
# /RNA/normed__I__hvgs
# ├── data (7549, 1995) float64
# └── reduction__pca__30__I
#     ├── ann__l2__63__63__48__4466
#     │   └── knn__21
#     ├── kmeans__100__4466
#     │   ├── cluster_centers (100, 30) float64
#     │   └── cluster_labels (7549,) float64
#     ├── mu (1995,) float64
#     ├── reduction (1995, 30) float64
#     └── sigma (1995,) float64
#
#   data: shape=(7549, 1995), dtype=float64, chunks=(2000, 2000)
# time: 60.6 ms (started: 2026-06-25 22:37:14 +02:00)
# /home/parashar/scarf/.venv/lib/python3.14/site-packages/zarr/core/group.py:3289: ZarrUserWarning: Object at ann_idx is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(

# %%
ds.load_graph(
    from_assay='RNA',
    cell_key='I',
    feat_key='hvgs',
    symmetric=False,
    upper_only=False
)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 158529 stored elements and shape (7549, 7549)>
# time: 65 ms (started: 2026-06-25 22:37:14 +02:00)

# %%
ds.show_zarr_tree(
    start='RNA/markers',
    depth=2
)
# Out:
# /RNA/markers
# └── I__RNA_cluster
#     ├── 1
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 10
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 11
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 12
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 13
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 14
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 15
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 16
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 17
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 18
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 19
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 2
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 20
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 3
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 4
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 5
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 6
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 7
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     ├── 8
#     │   ├── feature_index (13550,) int64
#     │   ├── fold_change (13550,) float64
#     │   ├── frac_exp (13550,) float64
#     │   ├── frac_exp_rest (13550,) float64
#     │   ├── mean (13550,) float64
#     │   ├── mean_rest (13550,) float64
#     │   └── score (13550,) float64
#     └── 9
#         ├── feature_index (13550,) int64
#         ├── fold_change (13550,) float64
#         ├── frac_exp (13550,) float64
#         ├── frac_exp_rest (13550,) float64
#         ├── mean (13550,) float64
#         ├── mean_rest (13550,) float64
#         └── score (13550,) float64
#
# time: 399 ms (started: 2026-06-25 22:37:14 +02:00)

# %%
ds.get_markers(
    group_key='RNA_cluster',
    group_id=7,
    min_score=0.1,
    min_frac_exp=0.1
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/group.py:737, in AsyncGroup.getitem(self, key)
#     736 try:
# --> 737     return await get_node(
#     738         store=store_path.store, path=store_path.path, zarr_format=self.metadata.zarr_format
#     739     )
#     740 except FileNotFoundError as e:
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/group.py:3561, in get_node(store, path, zarr_format)
#    3560 case 2:
# -> 3561     return await _get_node_v2(store=store, path=path)
#    3562 case 3:
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/group.py:3518, in _get_node_v2(store, path)
#    3504 """
#    3505 Read a Zarr v2 AsyncArray or AsyncGroup from a path in a Store.
#    3506
#    (...)   3516 AsyncArray | AsyncGroup
#    3517 """
# -> 3518 metadata = await _read_metadata_v2(store=store, path=path)
#    3519 return _build_node(store=store, path=path, metadata=metadata)
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/group.py:3409, in _read_metadata_v2(store, path)
#    3407 if zgroup_bytes is None:
#    3408     # neither .zarray or .zgroup were found results in KeyError
# -> 3409     raise FileNotFoundError(path)
#    3410 else:
#
# FileNotFoundError: RNA/markers/I__RNA_cluster/7/p_value
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 ds.get_markers(
#       2     group_key='RNA_cluster',
#       3     group_id=7,
#       4     min_score=0.1,
#
# File ~/scarf/scarf/datastore/datastore.py:681, in DataStore.get_markers(self, from_assay, cell_key, group_key, group_id, min_score, min_frac_exp)
#     679 group_name = str(gid)
#     680 if group_name in g:
# --> 681     cols = [g[group_name][x][:] for x in out_cols]  # type: ignore
#     682     df = pd.DataFrame(
#     683         cols,
#     684         index=out_cols,
#     685     ).T
#     686     df["group_id"] = gid
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/group.py:1843, in Group.__getitem__(self, path)
#    1813 def __getitem__(self, path: str) -> AnyArray | Group:
#    1814     """Obtain a group member.
#    1815
#    1816     Parameters
#    (...)   1841
#    1842     """
# -> 1843     obj = self._sync(self._async_group.getitem(path))
#    1844     if isinstance(obj, AsyncArray):
#    1845         return Array(obj)
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/sync.py:203, in SyncMixin._sync(self, coroutine)
#     200 def _sync[T](self, coroutine: Coroutine[Any, Any, T]) -> T:
#     201     # TODO: refactor this to to take *args and **kwargs and pass those to the method
#     202     # this should allow us to better type the sync wrapper
# --> 203     return sync(
#     204         coroutine,
#     205         timeout=config.get("async.timeout"),
#     206     )
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/sync.py:158, in sync(coro, loop, timeout)
#     155 return_result = next(iter(finished)).result()
#     157 if isinstance(return_result, BaseException):
# --> 158     raise return_result
#     159 else:
#     160     return return_result
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/sync.py:118, in _runner(coro)
#     113 """
#     114 Await a coroutine and return the result of running it. If awaiting the coroutine raises an
#     115 exception, the exception will be returned.
#     116 """
#     117 try:
# --> 118     return await coro
#     119 except Exception as ex:
#     120     return ex
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/group.py:741, in AsyncGroup.getitem(self, key)
#     737     return await get_node(
#     738         store=store_path.store, path=store_path.path, zarr_format=self.metadata.zarr_format
#     739     )
#     740 except FileNotFoundError as e:
# --> 741     raise KeyError(key) from e
#
# KeyError: 'p_value'
# time: 620 ms (started: 2026-06-25 22:37:15 +02:00)

# %%
ds.export_markers_to_csv(
    group_key='RNA_cluster',
    csv_filename='test.csv',
    min_score=0.2,
    min_frac_exp=0.1
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/group.py:737, in AsyncGroup.getitem(self, key)
#     736 try:
# --> 737     return await get_node(
#     738         store=store_path.store, path=store_path.path, zarr_format=self.metadata.zarr_format
#     739     )
#     740 except FileNotFoundError as e:
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/group.py:3561, in get_node(store, path, zarr_format)
#    3560 case 2:
# -> 3561     return await _get_node_v2(store=store, path=path)
#    3562 case 3:
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/group.py:3518, in _get_node_v2(store, path)
#    3504 """
#    3505 Read a Zarr v2 AsyncArray or AsyncGroup from a path in a Store.
#    3506
#    (...)   3516 AsyncArray | AsyncGroup
#    3517 """
# -> 3518 metadata = await _read_metadata_v2(store=store, path=path)
#    3519 return _build_node(store=store, path=path, metadata=metadata)
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/group.py:3409, in _read_metadata_v2(store, path)
#    3407 if zgroup_bytes is None:
#    3408     # neither .zarray or .zgroup were found results in KeyError
# -> 3409     raise FileNotFoundError(path)
#    3410 else:
#
# FileNotFoundError: RNA/markers/I__RNA_cluster/1/p_value
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 ds.export_markers_to_csv(
#       2     group_key='RNA_cluster',
#       3     csv_filename='test.csv',
#       4     min_score=0.2,
#
# File ~/scarf/scarf/datastore/datastore.py:746, in DataStore.export_markers_to_csv(self, from_assay, cell_key, group_key, csv_filename, min_score, min_frac_exp)
#     744 markers_table = {}
#     745 for group_id in sorted(set(clusters)):
# --> 746     m = self.get_markers(
#     747         from_assay=from_assay,
#     748         cell_key=cell_key,
#     749         group_key=group_key,
#     750         group_id=group_id,
#     751         min_score=min_score,
#     752         min_frac_exp=min_frac_exp,
#     753     )
#     754     if len(m) > 0:
#     755         markers_table[group_id] = m["feature_name"].reset_index(drop=True)
#
# File ~/scarf/scarf/datastore/datastore.py:681, in DataStore.get_markers(self, from_assay, cell_key, group_key, group_id, min_score, min_frac_exp)
#     679 group_name = str(gid)
#     680 if group_name in g:
# --> 681     cols = [g[group_name][x][:] for x in out_cols]  # type: ignore
#     682     df = pd.DataFrame(
#     683         cols,
#     684         index=out_cols,
#     685     ).T
#     686     df["group_id"] = gid
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/group.py:1843, in Group.__getitem__(self, path)
#    1813 def __getitem__(self, path: str) -> AnyArray | Group:
#    1814     """Obtain a group member.
#    1815
#    1816     Parameters
#    (...)   1841
#    1842     """
# -> 1843     obj = self._sync(self._async_group.getitem(path))
#    1844     if isinstance(obj, AsyncArray):
#    1845         return Array(obj)
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/sync.py:203, in SyncMixin._sync(self, coroutine)
#     200 def _sync[T](self, coroutine: Coroutine[Any, Any, T]) -> T:
#     201     # TODO: refactor this to to take *args and **kwargs and pass those to the method
#     202     # this should allow us to better type the sync wrapper
# --> 203     return sync(
#     204         coroutine,
#     205         timeout=config.get("async.timeout"),
#     206     )
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/sync.py:158, in sync(coro, loop, timeout)
#     155 return_result = next(iter(finished)).result()
#     157 if isinstance(return_result, BaseException):
# --> 158     raise return_result
#     159 else:
#     160     return return_result
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/sync.py:118, in _runner(coro)
#     113 """
#     114 Await a coroutine and return the result of running it. If awaiting the coroutine raises an
#     115 exception, the exception will be returned.
#     116 """
#     117 try:
# --> 118     return await coro
#     119 except Exception as ex:
#     120     return ex
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/group.py:741, in AsyncGroup.getitem(self, key)
#     737     return await get_node(
#     738         store=store_path.store, path=store_path.path, zarr_format=self.metadata.zarr_format
#     739     )
#     740 except FileNotFoundError as e:
# --> 741     raise KeyError(key) from e
#
# KeyError: 'p_value'
# time: 612 ms (started: 2026-06-25 22:37:15 +02:00)
