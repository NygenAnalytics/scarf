# %%
import scarf
import scarf.plotting as splt

scarf.fetch_dataset(
    "tenx_5K_pbmc_rnaseq",
    save_path="scarf_datasets",
    as_zarr=True,
)
ds = scarf.DataStore(
    "scarf_datasets/tenx_5K_pbmc_rnaseq/data.zarr",
    nthreads=4,
    min_features_per_cell=10,
)

# %%
ds.filter_cells(attrs=["RNA_nCounts"], highs=[15000], lows=[1000], reset_previous=True)
ds.mark_hvgs(min_cells=20, top_n=500)
ds.make_graph(feat_key="hvgs", k=11, dims=15)
ds.run_umap(n_epochs=150, parallel=True)
# Out:
# 597 cells flagged for filtering out using attribute RNA_nCounts
# Calculating summary statistics
# (RNA) feature stats block 1/102: read 0.0s (r2) compute 0.0s rss 326 MiB
# (RNA) feature stats block 2/102: read 0.0s (ram) compute 0.0s rss 339 MiB
# (RNA) feature stats block 3/102: read 0.0s (ram) compute 0.0s rss 344 MiB
# (RNA) feature stats block 4/102: read 0.0s (ram) compute 0.0s rss 351 MiB
# (RNA) feature stats block 5/102: read 0.0s (ram) compute 0.0s rss 359 MiB
# (RNA) feature stats block 6/102: read 0.0s (ram) compute 0.0s rss 371 MiB
# (RNA) feature stats block 7/102: read 0.0s (ram) compute 0.0s rss 378 MiB
# (RNA) feature stats block 8/102: read 0.0s (ram) compute 0.0s rss 386 MiB
# (RNA) feature stats block 9/102: read 0.0s (ram) compute 0.0s rss 393 MiB
# (RNA) feature stats block 10/102: read 0.0s (ram) compute 0.0s rss 393 MiB
# (RNA) feature stats block 11/102: read 0.0s (ram) compute 0.0s rss 393 MiB
# (RNA) feature stats block 12/102: read 0.0s (ram) compute 0.0s rss 393 MiB
# (RNA) feature stats block 13/102: read 0.0s (ram) compute 0.0s rss 393 MiB
# (RNA) feature stats block 14/102: read 0.0s (ram) compute 0.0s rss 393 MiB
# (RNA) feature stats block 15/102: read 0.0s (ram) compute 0.0s rss 393 MiB
# (RNA) feature stats block 16/102: read 0.0s (ram) compute 0.0s rss 393 MiB
# (RNA) feature stats block 17/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 18/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 19/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 20/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 21/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 22/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 23/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 24/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 25/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 26/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 27/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 28/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 29/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 30/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 31/102: read 0.0s (ram) compute 0.0s rss 394 MiB
# (RNA) feature stats block 32/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 33/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 34/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 35/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 36/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 37/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 38/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 39/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 40/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 41/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 42/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 43/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 44/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 45/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 46/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 47/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 48/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 49/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 50/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 51/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 52/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 53/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 54/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 55/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 56/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 57/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 58/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 59/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 60/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 61/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 62/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 63/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 64/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 65/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 66/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 67/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 68/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 69/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 70/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 71/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 72/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 73/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 74/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 75/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 76/102: read 0.0s (ram) compute 0.0s rss 398 MiB
# (RNA) feature stats block 77/102: read 0.0s (ram) compute 0.0s rss 405 MiB
# (RNA) feature stats block 78/102: read 0.0s (ram) compute 0.0s rss 405 MiB
# (RNA) feature stats block 79/102: read 0.0s (ram) compute 0.0s rss 405 MiB
# (RNA) feature stats block 80/102: read 0.0s (ram) compute 0.0s rss 405 MiB
# (RNA) feature stats block 81/102: read 0.0s (ram) compute 0.0s rss 405 MiB
# (RNA) feature stats block 82/102: read 0.0s (ram) compute 0.0s rss 413 MiB
# (RNA) feature stats block 83/102: read 0.0s (ram) compute 0.0s rss 420 MiB
# (RNA) feature stats block 84/102: read 0.0s (ram) compute 0.0s rss 427 MiB
# (RNA) feature stats block 85/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 86/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 87/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 88/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 89/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 90/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 91/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 92/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 93/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 94/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 95/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 96/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 97/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 98/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 99/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 100/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 101/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# (RNA) feature stats block 102/102: read 0.0s (ram) compute 0.0s rss 435 MiB
# Calculating HVGs
# 500 genes marked as HVGs
# make_graph step 1/7: normalize expression matrix (computing)
# make_graph step 1/7: normalize expression matrix finished in 0.6s (computing)
# make_graph step 2/7: normalization statistics (computing)
# make_graph step 2/7: normalization statistics finished in 0.0s (computing)
# make_graph step 3/7: dimension reduction, ANN index, and kmeans (computing)
# make_graph step 3/7: dimension reduction, ANN index, and kmeans finished in 0.6s (computing)
# make_graph step 4/7: persist graph artifacts to Zarr (computing)
# make_graph step 4/7: persist graph artifacts to Zarr finished in 0.1s (computing)
# make_graph step 5/7: KNN neighbor search (computing)
# make_graph step 5/7: KNN neighbor search finished in 0.1s (computing)
# make_graph step 6/7: smooth KNN distances into graph (computing)
# make_graph step 6/7: smooth KNN distances into graph finished in 10.2s (computing)
# ANN recall: 99.91%
# make_graph step 7/7: finalize graph metadata (computing)
# make_graph step 7/7: finalize graph metadata finished in 0.0s (computing)
# make_graph finished in 11.8s (7/7 steps, 11.7s in logged steps)
# Training UMAP:   0%|                                                                                          …

# %%
imputed_cd4 = ds.get_imputed(feature_name="CD4", t=2)
ds.cells.insert("CD4_imputed", imputed_cd4, overwrite=True)
splt.embedding(ds, layout_key="RNA_UMAP", color_by="CD4", show=False).figure

# %%
splt.embedding(ds, layout_key="RNA_UMAP", color_by="CD4_imputed", show=False).figure
