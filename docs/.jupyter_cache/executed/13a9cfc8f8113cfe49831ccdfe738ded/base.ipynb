# %%
import scarf
import scarf.plotting as splt

scarf.set_verbosity('WARNING')
scarf.__version__
# Out:
# '1.0.0'

# %%
scarf.fetch_dataset(
    dataset_name='kang_15K_pbmc_rnaseq',
    save_path='scarf_datasets',
    as_zarr=True
)

scarf.fetch_dataset(
    dataset_name='kang_14K_ifnb-pbmc_rnaseq', 
    save_path='scarf_datasets',
    as_zarr=True
)

# %%
ds_ctrl = scarf.DataStore(
    'scarf_datasets/kang_15K_pbmc_rnaseq/data.zarr/',
    nthreads=4
)

ds_ctrl
# Out:
# DataStore has 8487 (14619) cells with 1 assays: RNA
#    Cell metadata:
#             'I', 'ids', 'names', 'cluster_labels', 'RNA_percentMito',
#             'RNA_nFeatures', 'RNA_unified_tSNE2', 'RNA_percentRibo', 'RNA_unified_UMAP1', 'RNA_leiden_cluster',
#             'RNA_nCounts', 'RNA_UMAP2', 'reference_batch', 'RNA_unified_UMAP2', 'RNA_unified_tSNE1',
#             'RNA_UMAP1'
#    RNA assay has 11352 (35635) features and following metadata:
#             'I', 'ids', 'names', 'nCells', 'I__hvgs',
#             'dropOuts'
#       Projected samples:
#             'stim_symphony', 'control_symphony', 'stim'
#       Co-embeddings:
#             'unified_tSNE', 'unified_UMAP'

# %%
ds_stim = scarf.DataStore(
    'scarf_datasets/kang_14K_ifnb-pbmc_rnaseq/data.zarr',
    nthreads=4
)

ds_stim
# Out:
# DataStore has 10111 (14446) cells with 1 assays: RNA
#    Cell metadata:
#             'I', 'ids', 'names', 'RNA_percentMito', 'cluster_labels',
#             'RNA_percentRibo', 'symphony_labels', 'transferred_labels', 'RNA_nCounts', 'RNA_nFeatures',
#             'RNA_UMAP2', 'RNA_leiden_cluster', 'RNA_UMAP1'
#    RNA assay has 11051 (35635) features and following metadata:
#             'I', 'ids', 'names', 'I__hvgs', 'nCells',
#             'dropOuts'

# %%
scarf.AssayMerge(
    zarr_path='scarf_datasets/kang_merged_pbmc_rnaseq.zarr',
    assays=[ds_ctrl.RNA, ds_stim.RNA],
    names=['ctrl', 'stim'],
    merge_assay_name='RNA',
    prepend_text='orig',
    reset_cell_filter=False,
    source_column='sample_id',
    overwrite=True,
).dump()

# %%
ds = scarf.DataStore(
    'scarf_datasets/kang_merged_pbmc_rnaseq.zarr',
    nthreads=4
)
# Out:
# Minimum cell count (562) is lower than size factor multiplier (1000)

# %%
ds
# Out:
# DataStore has 18598 (29065) cells with 1 assays: RNA
#    Cell metadata:
#             'I', 'ids', 'names', 'orig_RNA_unified_tSNE1', 'RNA_percentMito',
#             'orig_RNA_UMAP1', 'orig_RNA_nCounts', 'orig_RNA_percentMito', 'orig_symphony_labels', 'orig_RNA_unified_UMAP1',
#             'orig_RNA_percentRibo', 'orig_RNA_UMAP2', 'orig_cluster_labels', 'orig_transferred_labels', 'RNA_percentRibo',
#             'RNA_nFeatures', 'orig_RNA_unified_tSNE2', 'orig_reference_batch', 'orig_RNA_nFeatures', 'orig_RNA_leiden_cluster',
#             'RNA_nCounts', 'orig_RNA_unified_UMAP2', 'sample_id'
#    RNA assay has 12450 (35635) features and following metadata:
#             'I', 'ids', 'names', 'dropOuts', 'nCells',

# %%
ds.cells.head()
# Out:
#        I                     ids             names  orig_RNA_unified_tSNE1  \
# 0  False  ctrl__TGTTAAGACACTGA-1  TGTTAAGACACTGA-1                     NaN
# 1  False  ctrl__TCACCCGAGCTATG-1  TCACCCGAGCTATG-1                     NaN
# 2   True  ctrl__TCACCCGAACCACA-1  TCACCCGAACCACA-1                2.102622
# 3   True  ctrl__TGTAGTCTACCAGT-1  TGTAGTCTACCAGT-1               -0.915313
# 4   True  ctrl__TATCAGCTAGTAGA-1  TATCAGCTAGTAGA-1              -13.961505
#
#    orig_RNA_nCounts  RNA_percentMito  orig_RNA_UMAP1  orig_RNA_unified_UMAP1  \
# 0             574.0         0.000000             NaN                     NaN
# 1            1682.0         0.000000             NaN                     NaN
# 2            1168.0         0.171233       -1.768571               -1.236308
# 3            2158.0         0.185357       -3.052445               -6.475383
# 4            1395.0         0.143369      -12.654625              -11.850616
#
#   orig_symphony_labels  orig_RNA_percentRibo  ...  orig_transferred_labels  \
# 0                  nan             20.034843  ...                      nan
# 1                  nan              0.059453  ...                      nan
# 2                  nan             31.763699  ...                      nan
# 3                  nan             32.483781  ...                      nan
# 4                  nan             34.695341  ...                      nan
#
#    orig_cluster_labels  orig_reference_batch RNA_nFeatures orig_RNA_nFeatures  \
# 0                  nan               control         304.0              304.0
# 1                  nan               control          62.0               62.0
# 2         CD4 Memory T               control         434.0              434.0
# 3                CD8 T               control         837.0              837.0
# 4                    B               control         592.0              592.0
#
#   orig_RNA_unified_tSNE2  orig_RNA_leiden_cluster  orig_RNA_unified_UMAP2  \
# 0                    NaN                       -1                     NaN
# 1                    NaN                       -1                     NaN
# 2              -6.651179                        1               -0.795045
# 3             -15.994447                        7              -10.047232
# 4              -6.759819                        5               -4.218987
#
#    sample_id  RNA_nCounts
# 0       ctrl        574.0
# 1       ctrl       1682.0
# 2       ctrl       1168.0
# 3       ctrl       2158.0
# 4       ctrl       1395.0
#
# [5 rows x 23 columns]

# %%
ds.cells.to_pandas_dataframe(
    ['sample_id'],
    key='I'
)['sample_id'].value_counts()
# Out:
# sample_id
# stim    10111
# ctrl     8487
# Name: count, dtype: int64

# %%
ds.mark_hvgs(
    min_cells=10,
    top_n=2000,
    min_mean=-3, 
    max_mean=2,
    max_var=6
)

# %%
ds.make_graph(
    feat_key='hvgs',
    k=21, 
    dims=25,
    n_centroids=100
)

# %%
ds.run_umap(
    n_epochs=250, 
    spread=5,
    min_dist=1,
    parallel=True
)

# %%
ds.cells.head()
# Out:
#        I                     ids             names  RNA_percentMito  \
# 0  False  ctrl__TGTTAAGACACTGA-1  TGTTAAGACACTGA-1         0.000000
# 1  False  ctrl__TCACCCGAGCTATG-1  TCACCCGAGCTATG-1         0.000000
# 2   True  ctrl__TCACCCGAACCACA-1  TCACCCGAACCACA-1         0.171233
# 3   True  ctrl__TGTAGTCTACCAGT-1  TGTAGTCTACCAGT-1         0.185357
# 4   True  ctrl__TATCAGCTAGTAGA-1  TATCAGCTAGTAGA-1         0.143369
#
#    orig_RNA_unified_tSNE1  orig_RNA_nCounts  orig_RNA_UMAP1  \
# 0                     NaN             574.0             NaN
# 1                     NaN            1682.0             NaN
# 2                2.102622            1168.0       -1.768571
# 3               -0.915313            2158.0       -3.052445
# 4              -13.961505            1395.0      -12.654625
#
#    orig_RNA_unified_UMAP1 orig_symphony_labels  orig_RNA_UMAP2  ...  \
# 0                     NaN                  nan             NaN  ...
# 1                     NaN                  nan             NaN  ...
# 2               -1.236308                  nan       -5.990341  ...
# 3               -6.475383                  nan      -12.830768  ...
# 4              -11.850616                  nan       -5.425503  ...
#
#    orig_transferred_labels  orig_RNA_unified_tSNE2 RNA_nFeatures  \
# 0                      nan                     NaN         304.0
# 1                      nan                     NaN          62.0
# 2                      nan               -6.651179         434.0
# 3                      nan              -15.994447         837.0
# 4                      nan               -6.759819         592.0
#
#    orig_RNA_leiden_cluster  orig_reference_batch RNA_nCounts  \
# 0                       -1               control       574.0
# 1                       -1               control      1682.0
# 2                        1               control      1168.0
# 3                        7               control      2158.0
# 4                        5               control      1395.0
#
#    orig_RNA_unified_UMAP2  sample_id  RNA_UMAP2  RNA_UMAP1
# 0                     NaN       ctrl        NaN        NaN
# 1                     NaN       ctrl        NaN        NaN
# 2               -0.795045       ctrl  14.474957  14.810422
# 3              -10.047232       ctrl   1.698806  21.302422
# 4               -4.218987       ctrl  20.109905 -17.987539
#
# [5 rows x 25 columns]

# %%
splt.embedding(
    ds,
    layout_key='RNA_UMAP',
    color_by='sample_id',
    legend_loc='right',
)
# Out:
# PlotResult(axes=1, tables=0, legends=1, scales=2, owns_figure=True, rendered=True)

# %%
splt.embedding(
    ds,
    layout_key='RNA_UMAP',
    color_by='orig_cluster_labels',
    legend_loc='right',
)
# Out:
# PlotResult(axes=1, tables=0, legends=1, scales=2, owns_figure=True, rendered=True)

# %%
ds.cells.insert(
    column_name=f'is_ctrl',
    values=(ds.cells.fetch_all('sample_id') == 'ctrl'),
    overwrite=True
)

# %%
ds.make_graph(
    feat_key='hvgs',
    k=21, 
    dims=25,
    n_centroids=100,
    pca_cell_key='is_ctrl'
)

# %%
ds.run_umap(
    n_epochs=250, 
    spread=5,
    min_dist=1,
    parallel=True,
    label='pUMAP'
)

# %%
splt.embedding(
    ds,
    layout_key='RNA_pUMAP',
    color_by='sample_id',
    legend_loc='right',
)
# Out:
# PlotResult(axes=1, tables=0, legends=1, scales=2, owns_figure=True, rendered=True)

# %%
splt.embedding(
    ds,
    layout_key='RNA_pUMAP',
    color_by='orig_cluster_labels',
    legend_loc='right',
)
# Out:
# PlotResult(axes=1, tables=0, legends=1, scales=2, owns_figure=True, rendered=True)

# %%
ds.make_graph(
    feat_key='hvgs',
    k=21,
    dims=25,
    n_centroids=100,
    harmonize=True,
    batch_columns=['sample_id'],
)

ds.run_umap(
    n_epochs=250,
    spread=5,
    min_dist=1,
    parallel=True,
    label='hUMAP'
)

ds.run_leiden_clustering(resolution=1.0)

# %%
splt.embedding(
    ds,
    layout_key='RNA_hUMAP',
    color_by='sample_id',
    legend_loc='right',
)

splt.embedding(
    ds,
    layout_key='RNA_hUMAP',
    color_by='orig_cluster_labels',
    legend_loc='right',
)
# Out:
# PlotResult(axes=1, tables=0, legends=1, scales=2, owns_figure=True, rendered=True)

# %%
ds.metric_lisi(
    label_colnames=['sample_id', 'orig_cluster_labels'],
    save_result=True,
    perplexity=7,
)
# Out:
# [('sample_id',
#   array([1.23625901, 1.17942804, 1.33316355, ..., 1.84760332, 1.98844051,
#          1.61671253], shape=(18598,))),
#  ('orig_cluster_labels',
#   array([1.        , 1.04153798, 1.49017685, ..., 1.        , 1.13581301,
#          1.        ], shape=(18598,)))]

# %%
ds.metric_ilisi(batch_colname='sample_id', perplexity=7)
# Out:
# 0.19296380177450323

# %%
ds.metric_clisi(label_colname='orig_cluster_labels', perplexity=7)
# Out:
# 0.9979824515704211

# %%
ds.metric_proportional_batch_mixing(label_colname='sample_id', perplexity=7)
# Out:
# 0.3418633962673361

# %%
ds.metric_graph_connectivity(label_colname='orig_cluster_labels')
# Out:
# 0.9551386034148828

# %%
ds.metric_graph_silhouette(res_label='leiden_cluster')
# Out:
# array([ 0.02488094,  0.08685683,  0.18735732,  0.10992459,  0.20124428,
#         0.36118883,  0.23056164,  0.07935803,  0.12434942, -0.00893679,
#         0.23190273,  0.27458349,  0.17185568,  0.36251517, -0.04664297,
#         0.42001305,  0.19039756])

# %%
ds.metric_label_concordance(
    label_columns=['RNA_leiden_cluster', 'orig_cluster_labels'],
    metric='ari'
)
# Out:
# 0.8546022504136203
