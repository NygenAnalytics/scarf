# %%
import scarf
import scarf.plotting as splt

scarf.set_verbosity('WARNING')

scarf.fetch_dataset(
    'tenx_5K_pbmc_rnaseq',
    save_path='scarf_datasets'
)

# %%
reader = scarf.CrH5Reader('scarf_datasets/tenx_5K_pbmc_rnaseq/data.h5')
reader.nCells, reader.nFeatures
# Out:
# (5025, 33538)

# %%
writer = scarf.CrToZarr(
    reader,
    zarr_loc='scarf_datasets/tenx_5K_pbmc_rnaseq/data.zarr',
    chunk_size=(2000, 1000)
)
writer.dump(batch_size=1000)

# %%
ds = scarf.DataStore(
    'scarf_datasets/tenx_5K_pbmc_rnaseq/data.zarr',
    nthreads=4,
    min_features_per_cell=10
)
ds
# Out:
# Minimum cell count (502) is lower than size factor multiplier (1000)
# DataStore has 5025 (5025) cells with 1 assays: RNA
#    Cell metadata:
#             'I', 'ids', 'names', 'RNA_percentMito', 'RNA_percentRibo',
#             'RNA_nFeatures', 'RNA_nCounts'
#    RNA assay has 14283 (33538) features and following metadata:
#             'I', 'ids', 'names', 'dropOuts', 'nCells',

# %%
qc_cols = [
    c for c in (
        'RNA_nCounts', 'RNA_nFeatures', 'RNA_percentMito', 'RNA_percentRibo'
    )
    if c in ds.cells.columns
]
qc_df = ds.cells.to_pandas_dataframe(qc_cols)
qc_df['groups'] = 0
splt.qc(qc_df)

# %%
ds.filter_cells(
    attrs=['RNA_nCounts', 'RNA_nFeatures', 'RNA_percentMito'],
    highs=[15000, 4000, 15],
    lows=[1000, 500, 0]
)

# %%
qc_df = ds.cells.to_pandas_dataframe(qc_cols)
qc_df['groups'] = 0
qc_df = qc_df.reindex(ds.cells.active_index('I'))
splt.qc(qc_df, color='coral')
ds.cells.head()
# Out:
#        I                 ids               names  RNA_percentMito  \
# 0   True  AAACCCAAGCGTATGG-1  AAACCCAAGCGTATGG-1        10.844353
# 1   True  AAACCCAGTCCTACAA-1  AAACCCAGTCCTACAA-1         5.975687
# 2  False  AAACCCATCACCTCAC-1  AAACCCATCACCTCAC-1        53.430353
# 3   True  AAACGCTAGGGCATGT-1  AAACGCTAGGGCATGT-1        10.919143
# 4   True  AAACGCTGTAGGTACG-1  AAACGCTGTAGGTACG-1         7.955407
#
#    RNA_percentRibo  RNA_nCounts  RNA_nFeatures
# 0        16.783630      13537.0         3503.0
# 1        20.034733      12668.0         3381.0
# 2         2.494802        962.0          346.0
# 3        28.783690       5788.0         1799.0
# 4        35.750038      13186.0         2887.0

# %%
ds.RNA.sf
# Out:
# 1000

# %%
ds.mark_hvgs(
    min_cells=20,
    top_n=500,
    min_mean=-3,
    max_mean=2,
    max_var=6
)
ds.RNA.feats.head()
# Out:
#        I              ids        names  nCells  dropOuts  I__hvgs  \
# 0  False  ENSG00000243485  MIR1302-2HG       0      5025    False
# 1  False  ENSG00000237613      FAM138A       0      5025    False
# 2  False  ENSG00000186092        OR4F5       0      5025    False
# 3   True  ENSG00000238009   AL627309.1      49      4976    False
# 4  False  ENSG00000239945   AL627309.3       3      5022    False
#
#    stats_I_sigmas  stats_I_normed_n  stats_I_avg  stats_I_normed_tot  \
# 0             NaN               NaN          NaN                 NaN
# 1             NaN               NaN          NaN                 NaN
# 2             NaN               NaN          NaN                 NaN
# 3        0.000196              33.0     0.001166            4.593283
# 4             NaN               NaN          NaN                 NaN
#
#    stats_I_c_var__200__0.1  stats_I_nz_mean
# 0                      NaN              NaN
# 1                      NaN              NaN
# 2                      NaN              NaN
# 3                   1.5279          0.13919
# 4                      NaN              NaN

# %%
ds.make_graph(
    feat_key='hvgs',
    k=11,
    dims=15,
    n_centroids=100
)

# %%
ds.run_umap(
    n_epochs=250,
    spread=5,
    min_dist=1,
    parallel=True
)
ds.cells.head()
# Out:
#        I                 ids               names  RNA_percentMito  \
# 0   True  AAACCCAAGCGTATGG-1  AAACCCAAGCGTATGG-1        10.844353
# 1   True  AAACCCAGTCCTACAA-1  AAACCCAGTCCTACAA-1         5.975687
# 2  False  AAACCCATCACCTCAC-1  AAACCCATCACCTCAC-1        53.430353
# 3   True  AAACGCTAGGGCATGT-1  AAACGCTAGGGCATGT-1        10.919143
# 4   True  AAACGCTGTAGGTACG-1  AAACGCTGTAGGTACG-1         7.955407
#
#    RNA_percentRibo  RNA_UMAP2  RNA_nFeatures  RNA_nCounts  RNA_UMAP1
# 0        16.783630  26.756128         3503.0      13537.0   7.147699
# 1        20.034733  24.933743         3381.0      12668.0  -9.907979
# 2         2.494802        NaN          346.0        962.0        NaN
# 3        28.783690  11.913174         1799.0       5788.0   1.791348
# 4        35.750038  -8.745583         2887.0      13186.0 -13.026900

# %%
splt.embedding(ds, layout_key='RNA_UMAP', show=False).figure;

# %%
splt.embedding(
    ds,
    layout_key='RNA_UMAP',
    color_by='RNA_nCounts',
    color_scale=splt.ColorScale(cmap='coolwarm'),
    show=False,
).figure;

# %%
ds.run_leiden_clustering(resolution=0.5)

# %%
splt.embedding(
    ds,
    layout_key='RNA_UMAP',
    color_by='RNA_leiden_cluster',
    show=False,
).figure;

# %%
leiden_clusters = ds.cells.to_pandas_dataframe(
    columns=['RNA_leiden_cluster'],
    key='I'
)
leiden_clusters.head()
# Out:
#    RNA_leiden_cluster
# 0                   2
# 1                   2
# 3                   7
# 4                   1
# 6                   5

# %%
ds.run_marker_search(
    group_key='RNA_leiden_cluster',
    gene_batch_size=100
)

# %%
splt.marker_heatmap(
    ds,
    group_key='RNA_leiden_cluster',
    topn=5,
    figsize=(5, 9)
)

# %%
df = ds.get_markers(
    group_key='RNA_leiden_cluster',
    group_id='1',
    min_score=-1,
    min_frac_exp=-1
)
df.head()
# Out:
#   group_id feature_name    score     mean  mean_rest  frac_exp  frac_exp_rest  \
# 0        1        ADTRP  0.64732  0.04316    0.00283   0.23978        0.02265
# 1        1      ANKRD55  0.55468  0.02194    0.00123   0.14836        0.01003
# 2        1        TSHZ2  0.51036  0.07179    0.01107   0.32638        0.05050
# 3        1        TCEA3  0.48633  0.03191    0.00421   0.21091        0.03342
# 4        1    CHRM3-AS2  0.48186  0.06784    0.00849   0.38332        0.05941
#
#    fold_change        p_value  feature_index
# 0     15.26714  1.987595e-109           4325
# 1     17.77451   4.367807e-72           3795
# 2      6.48604  1.951616e-121          12544
# 3      7.57451   1.767758e-75            225
# 4      7.98771  6.859238e-150           1437

# %%
splt.embedding(
    ds,
    layout_key='RNA_UMAP',
    color_by='CD14',
    sort_values=True,
    show=False,
).figure;
