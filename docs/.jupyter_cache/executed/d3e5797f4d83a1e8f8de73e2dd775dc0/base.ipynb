# %%
# %load_ext autotime

import scarf

scarf.__version__
# Out:
# '1.0.0'
# time: 1.63 s (started: 2026-07-02 22:14:23 +02:00)

# %%
scarf.show_available_datasets()
# Out:
# annotations
# baron_8K_pancreas_rnaseq
# bastidas-ponce_4K_pancreas-d15_rnaseq
# cao_2.1M_moca_rnaseq
# cusanovich_81K_mouse_atacseq
# hca_783K_blood_rnaseq
# kang_14K_ifnb-pbmc_rnaseq
# kang_15K_pbmc_rnaseq
# lecun_60K_mnist_images
# motifs
# muraro_2K_pancreas_rnaseq
# saunders_110K_brain_rnaseq
# segerstolpe_2K_pancreas_rnaseq
# tenx_1.3M_brain_rnaseq
# tenx_10K_pbmc-v1_atacseq
# tenx_3K_pbmc_multiome-gex-atac
# tenx_5K_pbmc_rnaseq
# tenx_8K_pbmc_citeseq
# xin_1K_pancreas_rnaseq
# zalando_60K_fmnist_images
# zeisel_161K_nervous_rnaseq
# zheng_69K_pbmc_rnaseq
# time: 19.2 s (started: 2026-07-02 22:14:24 +02:00)

# %%
# This dataset is in Cellranger (10x) HDF5 format.
scarf.fetch_dataset(
    dataset_name="tenx_10K_pbmc-v1_atacseq", save_path="./scarf_datasets"
)
# Out:
# time: 5.58 s (started: 2026-07-02 22:14:43 +02:00)

# %%
# This dataset is in MTX format along with barcodes and features TSV files.
scarf.fetch_dataset(dataset_name="xin_1K_pancreas_rnaseq", save_path="./scarf_datasets")
# Out:
# time: 9.61 s (started: 2026-07-02 22:14:49 +02:00)

# %%
# This dataset is in H5ad (anndata) format.
scarf.fetch_dataset(
    dataset_name="bastidas-ponce_4K_pancreas-d15_rnaseq", save_path="./scarf_datasets"
)
# Out:
# time: 3.88 s (started: 2026-07-02 22:14:58 +02:00)

# %%
# Change file_type to 'rna' in case of sc-RNA-seq or CITE-Seq
reader = scarf.CrH5Reader("scarf_datasets/tenx_10K_pbmc-v1_atacseq/data.h5")

# change value of `zarr_loc` to your choice of filename and path
writer = scarf.CrToZarr(reader, zarr_loc="scarf_datasets/pbmc_atac.zarr")
writer.dump()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 11
#       7 writer = scarf.CrToZarr(
#       8     reader,
#       9     zarr_loc='scarf_datasets/pbmc_atac.zarr'
#      10 )
# ---> 11 writer.dump()
#
# File ~/scarf/scarf/writers.py:376, in CrToZarr.dump(self, batch_size, lines_in_mem)
#     374     idx = idx | temp
#     375 if idx.sum() > 0:
# --> 376     stores[assay].set_coordinate_selection(
#     377         (s + a.row[idx], feat_coords[idx]), a.data[idx]
#     378     )
#     379 else:
#     380     logger.warning(
#     381         f"No feature captured from chunk {s} to {s + a.shape[0]} for assay: {assay}"
#     382     )
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/array.py:3554, in Array.set_coordinate_selection(self, selection, value, fields, prototype)
#    3546 if not is_scalar(value, self.dtype) and (
#    3547     isinstance(value, NDArrayLike) and indexer.shape != value.shape
#    3548 ):
#    3549     raise ValueError(
#    3550         f"Attempting to set a selection of {indexer.sel_shape[0]} "
#    3551         f"elements with an array of {value.shape[0]} elements."
#    3552     )
# -> 3554 sync(self.async_array._set_selection(indexer, value, fields=fields, prototype=prototype))
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/sync.py:158, in sync(coro, loop, timeout)
#     155 return_result = next(iter(finished)).result()
#     157 if isinstance(return_result, BaseException):
# --> 158     raise return_result
#     159 else:
#     160     return return_result
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/sync.py:118, in _runner(coro)
#     113 """
#     114 Await a coroutine and return the result of running it. If awaiting the coroutine raises an
#     115 exception, the exception will be returned.
#     116 """
#     117 try:
# --> 118     return await coro
#     119 except Exception as ex:
#     120     return ex
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/array.py:1553, in AsyncArray._set_selection(self, indexer, value, prototype, fields)
#    1545 async def _set_selection(
#    1546     self,
#    1547     indexer: Indexer,
#    (...)   1551     fields: Fields | None = None,
#    1552 ) -> None:
# -> 1553     return await _set_selection(
#    1554         self.store_path,
#    1555         self.metadata,
#    1556         self.codec_pipeline,
#    1557         self.config,
#    1558         self._chunk_grid,
#    1559         indexer,
#    1560         value,
#    1561         prototype=prototype,
#    1562         fields=fields,
#    1563     )
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/array.py:5795, in _set_selection(store_path, metadata, codec_pipeline, config, chunk_grid, indexer, value, prototype, fields)
#    5792     _config = replace(_config, order=order)
#    5794 # merging with existing data and encoding chunks
# -> 5795 await codec_pipeline.write(
#    5796     [
#    5797         (
#    5798             store_path / metadata.encode_chunk_key(chunk_coords),
#    5799             _get_chunk_spec(metadata, chunk_grid, chunk_coords, _config, prototype),
#    5800             chunk_selection,
#    5801             out_selection,
#    5802             is_complete_chunk,
#    5803         )
#    5804         for chunk_coords, chunk_selection, out_selection, is_complete_chunk in indexer
#    5805     ],
#    5806     value_buffer,
#    5807     drop_axes=indexer.drop_axes,
#    5808 )
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/codec_pipeline.py:620, in BatchedCodecPipeline.write(self, batch_info, value, drop_axes)
#     614 async def write(
#     615     self,
#     616     batch_info: Iterable[tuple[ByteSetter, ArraySpec, SelectorTuple, SelectorTuple, bool]],
#     617     value: NDBuffer,
#     618     drop_axes: tuple[int, ...] = (),
#     619 ) -> None:
# --> 620     await concurrent_map(
#     621         [
#     622             (single_batch_info, value, drop_axes)
#     623             for single_batch_info in batched(batch_info, self.batch_size)
#     624         ],
#     625         self.write_batch,
#     626         config.get("async.concurrency"),
#     627     )
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/common.py:110, in concurrent_map(items, func, limit)
#     107     async with sem:
#     108         return await func(*item)
# --> 110 return await asyncio.gather(*[asyncio.ensure_future(run(item)) for item in items])
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/common.py:108, in concurrent_map.<locals>.run(item)
#     106 async def run(item: tuple[Any]) -> V:
#     107     async with sem:
# --> 108         return await func(*item)
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/codec_pipeline.py:482, in BatchedCodecPipeline.write_batch(self, batch_info, value, drop_axes)
#     475         await self.encode_partial_batch(
#     476             [
#     477                 (byte_setter, value, chunk_selection, chunk_spec)
#     478                 for byte_setter, chunk_spec, chunk_selection, out_selection, _ in batch_info
#     479             ],
#     480         )
#     481     else:
# --> 482         await self.encode_partial_batch(
#     483             [
#     484                 (byte_setter, value[out_selection], chunk_selection, chunk_spec)
#     485                 for byte_setter, chunk_spec, chunk_selection, out_selection, _ in batch_info
#     486             ],
#     487         )
#     489 else:
#     490     # Read existing bytes if not total slice
#     491     async def _read_key(
#     492         byte_setter: ByteSetter | None, prototype: BufferPrototype
#     493     ) -> Buffer | None:
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/codec_pipeline.py:362, in BatchedCodecPipeline.encode_partial_batch(self, batch_info)
#     360 assert self.supports_partial_encode
#     361 assert isinstance(self.array_bytes_codec, ArrayBytesCodecPartialEncodeMixin)
# --> 362 await self.array_bytes_codec.encode_partial(batch_info)
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/abc/codec.py:286, in ArrayBytesCodecPartialEncodeMixin.encode_partial(self, batch_info)
#     268 async def encode_partial(
#     269     self,
#     270     batch_info: Iterable[tuple[ByteSetter, NDBuffer, SelectorTuple, ArraySpec]],
#     271 ) -> None:
#     272     """Partially encodes a batch of chunks.
#     273     This method determines parts of a chunk from the slice selection, encodes them and
#     274     writes these parts to the store (via ByteSetter).
#    (...)    284         The chunk spec contains information about the chunk.
#     285     """
# --> 286     await concurrent_map(
#     287         list(batch_info),
#     288         self._encode_partial_single,
#     289         config.get("async.concurrency"),
#     290     )
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/common.py:110, in concurrent_map(items, func, limit)
#     107     async with sem:
#     108         return await func(*item)
# --> 110 return await asyncio.gather(*[asyncio.ensure_future(run(item)) for item in items])
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/common.py:108, in concurrent_map.<locals>.run(item)
#     106 async def run(item: tuple[Any]) -> V:
#     107     async with sem:
# --> 108         return await func(*item)
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/codecs/sharding.py:609, in ShardingCodec._encode_partial_single(self, byte_setter, shard_array, selection, shard_spec)
#     604     # Use vectorized lookup for better performance
#     605     shard_dict = shard_reader.to_dict_vectorized(
#     606         np.asarray(_morton_order(chunks_per_shard))
#     607     )
# --> 609 await self.codec_pipeline.write(
#     610     [
#     611         (
#     612             _ShardingByteSetter(shard_dict, chunk_coords),
#     613             chunk_spec,
#     614             chunk_selection,
#     615             out_selection,
#     616             is_complete_shard,
#     617         )
#     618         for chunk_coords, chunk_selection, out_selection, is_complete_shard in indexer
#     619     ],
#     620     shard_array,
#     621 )
#     622 buf = await self._encode_shard_dict(
#     623     shard_dict,
#     624     chunks_per_shard=chunks_per_shard,
#     625     buffer_prototype=default_buffer_prototype(),
#     626 )
#     628 if buf is None:
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/codec_pipeline.py:620, in BatchedCodecPipeline.write(self, batch_info, value, drop_axes)
#     614 async def write(
#     615     self,
#     616     batch_info: Iterable[tuple[ByteSetter, ArraySpec, SelectorTuple, SelectorTuple, bool]],
#     617     value: NDBuffer,
#     618     drop_axes: tuple[int, ...] = (),
#     619 ) -> None:
# --> 620     await concurrent_map(
#     621         [
#     622             (single_batch_info, value, drop_axes)
#     623             for single_batch_info in batched(batch_info, self.batch_size)
#     624         ],
#     625         self.write_batch,
#     626         config.get("async.concurrency"),
#     627     )
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/common.py:110, in concurrent_map(items, func, limit)
#     107     async with sem:
#     108         return await func(*item)
# --> 110 return await asyncio.gather(*[asyncio.ensure_future(run(item)) for item in items])
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/common.py:108, in concurrent_map.<locals>.run(item)
#     106 async def run(item: tuple[Any]) -> V:
#     107     async with sem:
# --> 108         return await func(*item)
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/codec_pipeline.py:551, in BatchedCodecPipeline.write_batch(self, batch_info, value, drop_axes)
#     548         else:
#     549             chunk_array_batch.append(chunk_array)
# --> 551 chunk_bytes_batch = await self.encode_batch(
#     552     [
#     553         (chunk_array, chunk_spec)
#     554         for chunk_array, (_, chunk_spec, *_) in zip(
#     555             chunk_array_batch, batch_info, strict=False
#     556         )
#     557     ],
#     558 )
#     560 async def _write_key(byte_setter: ByteSetter, chunk_bytes: Buffer | None) -> None:
#     561     if chunk_bytes is None:
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/codec_pipeline.py:349, in BatchedCodecPipeline.encode_batch(self, chunk_arrays_and_specs)
#     346 chunk_specs = resolve_batched(self.array_bytes_codec, chunk_specs)
#     348 for bb_codec in self.bytes_bytes_codecs:
# --> 349     chunk_bytes_batch = await bb_codec.encode(
#     350         zip(chunk_bytes_batch, chunk_specs, strict=False)
#     351     )
#     352     chunk_specs = resolve_batched(bb_codec, chunk_specs)
#     354 return chunk_bytes_batch
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/abc/codec.py:203, in BaseCodec.encode(self, chunks_and_specs)
#     187 async def encode(
#     188     self,
#     189     chunks_and_specs: Iterable[tuple[CI | None, ArraySpec]],
#     190 ) -> Iterable[CO | None]:
#     191     """Encodes a batch of chunks.
#     192     Chunks can be None in which case they are ignored by the codec.
#     193
#    (...)    201     Iterable[CodecOutput | None]
#     202     """
# --> 203     return await _batching_helper(self._encode_single, chunks_and_specs)
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/abc/codec.py:493, in _batching_helper(func, batch_info)
#     489 async def _batching_helper[CI: CodecInput, CO: CodecOutput](
#     490     func: Callable[[CI, ArraySpec], Awaitable[CO | None]],
#     491     batch_info: Iterable[tuple[CI | None, ArraySpec]],
#     492 ) -> list[CO | None]:
# --> 493     return await concurrent_map(
#     494         list(batch_info),
#     495         _noop_for_none(func),
#     496         config.get("async.concurrency"),
#     497     )
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/common.py:110, in concurrent_map(items, func, limit)
#     107     async with sem:
#     108         return await func(*item)
# --> 110 return await asyncio.gather(*[asyncio.ensure_future(run(item)) for item in items])
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/core/common.py:108, in concurrent_map.<locals>.run(item)
#     106 async def run(item: tuple[Any]) -> V:
#     107     async with sem:
# --> 108         return await func(*item)
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/abc/codec.py:506, in _noop_for_none.<locals>.wrap(chunk, chunk_spec)
#     504 if chunk is None:
#     505     return None
# --> 506 return await func(chunk, chunk_spec)
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/codecs/blosc.py:332, in BloscCodec._encode_single(self, chunk_bytes, chunk_spec)
#     327 async def _encode_single(
#     328     self,
#     329     chunk_bytes: Buffer,
#     330     chunk_spec: ArraySpec,
#     331 ) -> Buffer | None:
# --> 332     return await asyncio.to_thread(self._encode_sync, chunk_bytes, chunk_spec)
#
# File ~/.local/share/uv/python/cpython-3.14.4-linux-x86_64-gnu/lib/python3.14/asyncio/threads.py:25, in to_thread(func, *args, **kwargs)
#      23 ctx = contextvars.copy_context()
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File ~/.local/share/uv/python/cpython-3.14.4-linux-x86_64-gnu/lib/python3.14/concurrent/futures/thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File ~/.local/share/uv/python/cpython-3.14.4-linux-x86_64-gnu/lib/python3.14/concurrent/futures/thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File ~/scarf/.venv/lib/python3.14/site-packages/zarr/codecs/blosc.py:324, in BloscCodec._encode_sync(self, chunk_bytes, chunk_spec)
#     316 def _encode_sync(
#     317     self,
#     318     chunk_bytes: Buffer,
#    (...)    321     # Since blosc only support host memory, we convert the input and output of the encoding
#     322     # between numpy array and buffer
#     323     return chunk_spec.prototype.buffer.from_bytes(
# --> 324         self._blosc_codec.encode(chunk_bytes.as_numpy_array())
#     325     )
#
# File numcodecs/blosc.pyx:495, in numcodecs.blosc.Blosc.encode()
# --> 495 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/scarf/.venv/lib/python3.14/site-packages/numcodecs/compat.py:149, in ensure_contiguous_ndarray(buf, max_buffer_size, flatten)
#     120 def ensure_contiguous_ndarray(buf, max_buffer_size=None, flatten=True) -> np.ndarray:
#     121     """Convenience function to coerce `buf` to a numpy array, if it is not already a
#     122     numpy array. Also ensures that the returned value exports fully contiguous memory,
#     123     and supports the new-style buffer interface. If the optional max_buffer_size is
#    (...)    145     return a view on memory exported by `buf`.
#     146     """
#     148     return ensure_ndarray(
# --> 149         ensure_contiguous_ndarray_like(buf, max_buffer_size=max_buffer_size, flatten=flatten)
#     150     )
#
# File ~/scarf/.venv/lib/python3.14/site-packages/numcodecs/compat.py:115, in ensure_contiguous_ndarray_like(buf, max_buffer_size, flatten)
#     113 if max_buffer_size is not None and arr.nbytes > max_buffer_size:
#     114     msg = f"Codec does not support buffers of > {max_buffer_size} bytes"
# --> 115     raise ValueError(msg)
#     117 return arr
#
# ValueError: Codec does not support buffers of > 2147483647 bytes
# time: 32.4 s (started: 2026-07-02 22:15:01 +02:00)

# %%
# Note here we only give name of directory containing MTX file (along with barcodes and features file)
reader = scarf.CrDirReader("scarf_datasets/xin_1K_pancreas_rnaseq")

# change value of `zarr_loc` to your choice of filename and path
writer = scarf.CrToZarr(reader, zarr_loc="scarf_datasets/xin_1K.zarr")
writer.dump()
# Out:
# feature_types extraction failed from features.tsv.gz in column 2
# time: 8.63 s (started: 2026-07-02 22:15:33 +02:00)

# %%
# Note: H5adReader takes the path to the .h5ad file directly
reader = scarf.H5adReader(
    "scarf_datasets/bastidas-ponce_4K_pancreas-d15_rnaseq/data.h5ad",
    cell_ids_key="index",  # Where Cell/barcode ids are saved under 'obs' slot
    feature_ids_key="index",  # Where gene ids are saved under 'var' slot
    feature_name_key="gene_short_name",  # Where gene names are saved under 'var' slot
)

# change value of `zarr_loc` to your choice of filename and path
writer = scarf.H5adToZarr(
    reader, zarr_loc="scarf_datasets/differentiating_pancreatic_cells.zarr"
)
writer.dump()
# Out:
# No value provided for assay names. Will use default value: 'RNA'
# Could not find feature names key: gene_short_name in self.featureAttrsKey.
# time: 3.24 s (started: 2026-07-02 22:15:42 +02:00)

# %%
ds = scarf.DataStore("scarf_datasets/differentiating_pancreatic_cells.zarr")
# Out:
# time: 4.45 s (started: 2026-07-02 22:15:45 +02:00)

# %%
scarf.writers.to_mtx(assay=ds.RNA, mtx_directory="scarf_datasets/diff_pancreas")
# Out:
# time: 11.3 s (started: 2026-07-02 22:15:50 +02:00)

# %%
ds = scarf.DataStore("scarf_datasets/differentiating_pancreatic_cells.zarr")
# Out:
# time: 639 ms (started: 2026-07-02 22:16:01 +02:00)

# %%
scarf.writers.to_h5ad(assay=ds.RNA, h5ad_filename="scarf_datasets/diff_pancreas.h5ad")
# Out:
# time: 8.51 s (started: 2026-07-02 22:16:02 +02:00)
